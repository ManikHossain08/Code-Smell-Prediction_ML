# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC


def mainModels():
    df = pd.read_csv('/Users/manikhossain/Downloads/Py_R_Data/datasets.csv')
    smells = ['OSE', 'BCE', 'PDE', 'SV', 'OS', 'SDS', 'RS', 'TFS']

    model = Models()
    for smell in smells:
        print('### Predicting code smell "{}" ###'.format(smell))
        model.predict(df, smell)
        

def solve(numheads,numlegs):
        ns='No solutions!'
        for i in range(numheads+1):
            j=numheads-i
            if 2*i+4*j==numlegs:
                return i,j
        return ns,ns
    
    
    
class Models():

    def predict(self, df, feature):
        # train test split
        X = df.iloc[:, 1:24]
        y = df = df[[feature]]
        X_train, X_test, y_train, y_test = train_test_split(
            X, y, test_size=0.33, random_state=42)

        # Naive Bayes
        print('-- Naive Bayes --')
        clf = GaussianNB()
        self.output_accuracy(X, y, X_train, y_train, X_test, y_test, clf)

        # Random Forests
        print('-- Random Forests --')
        clf = RandomForestClassifier(
            n_estimators=100, max_depth=2, random_state=0)
        self.output_accuracy(X, y, X_train, y_train, X_test, y_test, clf)

        # C4.5 (J48)
        print('-- C4.5 (implented as J48 in Weka) --')
        clf = DecisionTreeClassifier(random_state=0)
        self.output_accuracy(X, y, X_train, y_train, X_test, y_test, clf)

        # Support Vector Machine using LIBSVM implementation with SMO
        print('-- Support Vector Machine using LIBSVM implementation with SMO --')
        clf = SVC(gamma='auto')
        self.output_accuracy(X, y, X_train, y_train, X_test, y_test, clf)

    def output_accuracy(self, X, y, X_train, y_train, X_test, y_test, clf):
        clf.fit(X_train, y_train.values.ravel())
        train_acc = clf.score(X_train, y_train.values.ravel())
        test_acc = clf.score(X_test, y_test.values.ravel())
        cv_scores = cross_val_score(clf, X, y.values.ravel(), cv=5)
        cv_acc = '{} (+/- {})'.format(cv_scores.mean(), cv_scores.std() * 2)
        print('Training accuray: {}'.format(train_acc))
        print('Testing accuray: {}'.format(test_acc))
        print('Cross-validation accuray: {}'.format(cv_acc))
        print('\n')
        
    
    
if __name__ == '__main__':
    mainModels()
    print('Some additional function for testing...........')
    numheads=35
    numlegs=94
    solutions = solve(numheads,numlegs)
    print (solutions)
# Out:
# ### Predicting code smell "OSE" ###
# -- Naive Bayes --
# Training accuray: 0.6938775510204082
# Testing accuray: 0.52
# Cross-validation accuray: 0.40476190476190477 (+/- 0.26255330956362327)
#
#
# -- Random Forests --
# Training accuray: 0.9795918367346939
# Testing accuray: 0.88
# Cross-validation accuray: 0.8238095238095238 (+/- 0.13866875979581944)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.92
# Cross-validation accuray: 0.9600000000000002 (+/- 0.10666666666666665)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.84
# Cross-validation accuray: 0.7971428571428572 (+/- 0.011428571428571477)
#
#
# (23, 12)
# ### Predicting code smell "BCE" ###
# -- Naive Bayes --
# Training accuray: 0.6938775510204082
# Testing accuray: 0.64
# Cross-validation accuray: 0.7 (+/- 0.2887340418772533)
#
#
# -- Random Forests --
# Training accuray: 0.9387755102040817
# Testing accuray: 0.88
# Cross-validation accuray: 0.9035714285714287 (+/- 0.07609741340236618)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.96
# Cross-validation accuray: 0.975 (+/- 0.06123724356957946)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.6
# Cross-validation accuray: 0.5678571428571428 (+/- 0.008748177652797033)
#
#
# (23, 12)
# ### Predicting code smell "PDE" ###
# -- Naive Bayes --
# Training accuray: 0.8367346938775511
# Testing accuray: 0.84
# Cross-validation accuray: 0.7422619047619048 (+/- 0.16117834237231324)
#
#
# -- Random Forests --
# Training accuray: 0.9795918367346939
# Testing accuray: 0.92
# Cross-validation accuray: 0.8377380952380952 (+/- 0.06568840069901657)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 1.0
# Cross-validation accuray: 0.8904761904761905 (+/- 0.1365596063156946)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.8
# Cross-validation accuray: 0.7165476190476191 (+/- 0.033675118491880235)
#
#
# (23, 12)
# ### Predicting code smell "SV" ###
# -- Naive Bayes --
# Training accuray: 0.5714285714285714
# Testing accuray: 0.44
# Cross-validation accuray: 0.5464285714285715 (+/- 0.43070895519089525)
#
#
# -- Random Forests --
# Training accuray: 0.9795918367346939
# Testing accuray: 0.96
# Cross-validation accuray: 0.9053571428571429 (+/- 0.06546536707079775)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 1.0
# Cross-validation accuray: 0.8767857142857144 (+/- 0.1684260874650228)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.96
# Cross-validation accuray: 0.9071428571428573 (+/- 0.05248906591678242)
#
#
# (23, 12)
# ### Predicting code smell "OS" ###
# -- Naive Bayes --
# Training accuray: 0.9387755102040817
# Testing accuray: 0.72
# Cross-validation accuray: 0.822857142857143 (+/- 0.2800971648708846)
#
#
# -- Random Forests --
# Training accuray: 1.0
# Testing accuray: 0.84
# Cross-validation accuray: 0.9180952380952381 (+/- 0.06095238095238101)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.88
# Cross-validation accuray: 0.9723809523809525 (+/- 0.06771957651288066)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.52
# Cross-validation accuray: 0.540952380952381 (+/- 0.030476190476190455)
#
#
# (23, 12)
# ### Predicting code smell "SDS" ###
# -- Naive Bayes --
# Training accuray: 0.673469387755102
# Testing accuray: 0.68
# Cross-validation accuray: 0.5257142857142857 (+/- 0.18285714285714286)
#
#
# -- Random Forests --
# Training accuray: 0.9795918367346939
# Testing accuray: 1.0
# Cross-validation accuray: 0.8933333333333333 (+/- 0.18086213288334052)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.96
# Cross-validation accuray: 0.9866666666666667 (+/- 0.05333333333333332)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.6
# Cross-validation accuray: 0.5942857142857143 (+/- 0.022857142857142864)
#
#
# (23, 12)
# ### Predicting code smell "RS" ###
# -- Naive Bayes --
# Training accuray: 0.5918367346938775
# Testing accuray: 0.52
# Cross-validation accuray: 0.5495238095238095 (+/- 0.4324942163376672)
#
#
# -- Random Forests --
# Training accuray: 0.9591836734693877
# Testing accuray: 0.88
# Cross-validation accuray: 0.8780952380952382 (+/- 0.055728528907915416)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.88
# Cross-validation accuray: 0.9066666666666666 (+/- 0.23247461032216926)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.88
# Cross-validation accuray: 0.8647619047619047 (+/- 0.007619047619047681)
#
#
# (23, 12)
# ### Predicting code smell "TFS" ###
# -- Naive Bayes --
# Training accuray: 0.6122448979591837
# Testing accuray: 0.64
# Cross-validation accuray: 0.5257142857142857 (+/- 0.31214857791423234)
#
#
# -- Random Forests --
# Training accuray: 0.9795918367346939
# Testing accuray: 0.84
# Cross-validation accuray: 0.8400000000000001 (+/- 0.26127890589687236)
#
#
# -- C4.5 (implented as J48 in Weka) --
# Training accuray: 1.0
# Testing accuray: 0.96
# Cross-validation accuray: 0.9466666666666667 (+/- 0.09977753031397174)
#
#
# -- Support Vector Machine using LIBSVM implementation with SMO --
# Training accuray: 1.0
# Testing accuray: 0.6
# Cross-validation accuray: 0.5942857142857143 (+/- 0.022857142857142864)
#
#
# (23, 12)
# Some additional function for testing...........
# (23, 12)
